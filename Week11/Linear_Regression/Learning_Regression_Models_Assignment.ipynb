# %% [markdown]
# # Multiple Linear Regression For Boston Housing Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Yasmeenmad/data_science_bootcamp/main/Week11/Linear_Regression/BostonHousing.csv")

# %%
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col1 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col2 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col3 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col4 {
#             background-color:  #f7b599;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col5 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col6 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col8 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col9 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col10 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col11 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col12 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row0_col13 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col2 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col4 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col5 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col6 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col8 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col9 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col10 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col11 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col12 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row1_col13 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col0 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col1 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col3 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col4 {
#             background-color:  #e0654f;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col5 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col6 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col7 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col8 {
#             background-color:  #f6a283;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col9 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col10 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col11 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col12 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row2_col13 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col0 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col1 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col2 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col4 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col5 {
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col7 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col8 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col9 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col10 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col11 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col12 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row3_col13 {
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row4_col0 {
#             background-color:  #efcebd;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row4_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row4_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_f4cbf16e_d367_11eb_bb6d_d85de2e0cf06row4_col3 {
#             background-color:  #779af7;
#             colo

# %% [markdown]
# Train / test split the data...

# %%
vars = ['rm', 'lstat']

target = 'medv'
X = df[vars]
y = df[target]

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, random_state=2)

# %%
X_train
# Out:
#         rm  lstat
# 312  6.023  11.72
# 328  5.868   9.97
# 251  6.438   3.59
# 205  5.891  10.87
# 231  7.412   5.25
# ..     ...    ...
# 22   6.142  18.72
# 72   6.065   5.52
# 493  5.707  12.01
# 15   5.834   8.47
# 168  6.319  11.10
#
# [379 rows x 2 columns]

# %%
y_test
# Out:
# 463    20.2
# 152    15.3
# 291    37.3
# 183    32.5
# 384     8.8
#        ...
# 160    27.0
# 438     8.4
# 282    46.0
# 294    21.7
# 7      27.1
# Name: medv, Length: 127, dtype: float64

# %%
multi_lr = LinearRegression()

# %%
multi_lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Find out a little bit about it...

# %%
multi_lr.intercept_
# Out:
# 1.0355165535077724

# %%
multi_lr.coef_
# Out:
# array([ 4.74338803, -0.66459738])

# %% [markdown]
# Make some predictions...

# %%
multi_predictions = multi_lr.predict(X_test)

# %% [markdown]
# Look at some preds and actuals side-by-side...

# %%
multi_predictions[-5:]
# Out:
# array([27.02640614,  6.57792172, 35.29827991, 22.62672248, 17.58466768])

# %%
y_test.tail()
# Out:
# 160    27.0
# 438     8.4
# 282    46.0
# 294    21.7
# 7      27.1
# Name: medv, dtype: float64

# %% [markdown]
# How'd we score?

# %%
r2_score(y_true=y_test, y_pred=multi_predictions)
# Out:
# 0.687388881816742

# %%
mean_absolute_error(y_true=y_test, y_pred=multi_predictions)
# Out:
# 3.6905227495488204

# %%
y_test.mean()
# Out:
# 22.93070866141732

# %%
y_test.std()
# Out:
# 9.45810739659681

# %% [markdown]
# The columns I chose were these two columns `rm` and `lstat`, because I found that they have the highest correlation with the `medv` column.
#
# And the first r2_score was: $0.7188657509609544$, and when we changed the columns the r2_score went down to $0.687388881816742$, Also the mean_absolute_error was: $4.363991882706358$, and became $3.6905227495488204$.
#
# We notice that the values have decreased and this is a good thing
